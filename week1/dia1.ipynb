# %% [markdown]
# # TU PRIMER LABORATORIO
# ### Por favor lee esta sección. Es valioso para prepararte, aunque sea una lectura larga -- es material importante.
#
# ### Además, ¡asegúrate de leer [README.md](../README.md)!
#
# ### Respuestas a las preguntas más comunes
#
# [Mi Cursor se ve diferente al tuyo (nueva pantalla de bienvenida)](https://edwarddonner.com/avatar?q=54)
# [¿Puedo usar Gemini o modelos gratis en lugar de OpenAI? ¡Sí!](https://edwarddonner.com/avatar?q=8)
# [Dónde están los recursos del curso](https://edwarddonner.com/2024/11/13/llm-engineering-resources/)
# [¿Cómo encaja este curso con tus otros cursos?](https://edwarddonner.com/curriculum)
# [¿Puedo tomar este curso sin experiencia en programación?](https://edwarddonner.com/avatar?q=2)
# [¿Qué trabajo puedo conseguir después de tomar este curso?](https://edwarddonner.com/avatar?q=3)
#
# ## Tu primer Proyecto de LLM de Frontera
#
# Al final de este curso, habrás construido una solución autónoma de IA Agéntica con 7 agentes que colaboran para resolver un problema de negocio. ¡Todo a su tiempo! Empezaremos con algo más pequeño...
#
# Nuestro objetivo es programar un nuevo tipo de Navegador Web. Dale una URL, y responderá con un resumen. ¡El Selecciones del Reader's Digest de internet!
#
# Antes de empezar, deberías haber completado la configuración enlazada en el README.
#
# ### Si eres nuevo trabajando en "Notebooks" (también conocidos como Labs o Jupyter Lab)
#
# ¡Bienvenido al maravilloso mundo de la experimentación en Ciencia de Datos! Simplemente haz clic en cada "celda" que tenga código, como la celda inmediatamente debajo de este texto, y presiona Shift+Return para ejecutar esa celda. Asegúrate de ejecutar cada celda, empezando desde arriba, en orden.
#
# Por favor revisa la [carpeta de Guías](../guides/01_intro.ipynb) para ver todas las guías.
#
# ## Estoy aquí para ayudar
#
# Si tienes algún problema, por favor contáctame.
# Estoy disponible a través de la plataforma, o en ed@edwarddonner.com, o en https://www.linkedin.com/in/eddonner/ si quieres conectar (¡y me encanta conectar!)
# Y también tengo un [canal de YouTube con contenido extra](https://youtube.com/@edward.donner).
# Y esto es nuevo para mí, pero también estoy probando X en [@edwarddonner](https://x.com/edwarddonner) - si estás en X, por favor muéstrame cómo se hace 😂
#
# ## Más solución de problemas
#
# Por favor revisa el notebook de [solución de problemas](../setup/troubleshooting.ipynb) en la carpeta setup para diagnosticar y arreglar problemas comunes. Al final del todo hay un script de diagnóstico con información útil para depurar.
#
# ## ¡Si esto ya lo sabes de memoria!
#
# Si ya te sientes cómodo con el material de hoy, por favor ten paciencia; puedes avanzar rápidamente por los primeros laboratorios - profundizaremos mucho más a medida que pasen las semanas. ¡Al final haremos fine-tuning de nuestro propio LLM para competir con OpenAI!
#
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Por favor lee - nota importante</h2>
#             <span style="color:#900;">La forma en que colaboro contigo puede ser diferente a otros cursos que hayas tomado. Prefiero no escribir código mientras tú miras. En cambio, ejecuto Jupyter Labs, como este, y te doy una intuición de lo que está pasando. Mi sugerencia es que lo ejecutes cuidadosamente tú mismo, <b>después</b> de ver la clase. Agrega instrucciones print para entender qué está pasando, y luego crea tus propias variaciones. Si tienes una cuenta de Github, úsala para mostrar tus variaciones. Esto no solo es práctica esencial, sino que demuestra tus habilidades a otros, incluyendo quizás futuros clientes o empleadores...</span>
#         </td>
#     </tr>
# </table>
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">Este código es un recurso vivo - mantente atento a mis correos</h2>
#             <span style="color:#f71;">Actualizo el código regularmente. A medida que la gente hace preguntas, agrego más ejemplos o mejores comentarios. Como resultado, notarás que el código de abajo no es idéntico a los videos. Todo lo de los videos está aquí; pero también he agregado mejores explicaciones y nuevos modelos como DeepSeek. Considera esto como un libro interactivo.<br/><br/>
#                 Intento enviar correos regularmente con actualizaciones importantes relacionadas con el curso. Puedes encontrar esto en la sección 'Announcements' de Udemy en la barra lateral izquierda. También puedes elegir recibir mis correos a través de tu Configuración de Notificaciones en Udemy. ¡Respeto tu bandeja de entrada y siempre intento agregar valor con mis correos!
#             </span>
#         </td>
#     </tr>
# </table>
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Valor de negocio de estos ejercicios</h2>
#             <span style="color:#181;">Una última reflexión. Aunque he diseñado estos notebooks para que sean educativos, también he intentado hacerlos entretenidos. Haremos cosas divertidas como hacer que los LLMs cuenten chistes y discutan entre ellos. Pero fundamentalmente, mi objetivo es enseñar habilidades que puedas aplicar en los negocios. Explicaré las implicaciones de negocio a medida que avancemos, y vale la pena tener esto en mente: a medida que ganes experiencia con modelos y técnicas, piensa en formas en que podrías poner esto en acción en tu trabajo hoy. Por favor contáctame si quieres discutir más o si tienes ideas para compartir conmigo.</span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### Si es necesario, instala las Extensiones de Cursor
#
# 1. Desde el menú View, selecciona Extensions
# 2. Busca Python
# 3. Haz clic en "Python" hecho por "ms-python" y selecciona Install si aún no está instalado
# 4. Busca Jupyter
# 5. Haz clic en "Jupyter" hecho por "ms-toolsai" y selecciona Install si aún no está instalado
#
#
# ### Ahora selecciona el Kernel
#
# Haz clic en "Select Kernel" en la esquina superior derecha
#
# Elige "Python Environments..."
#
# Luego elige el que se vea como `.venv (Python 3.12.x) .venv/bin/python` - debería estar marcado como "Recommended" y tener una estrella grande al lado.
#
# ¿Algún problema con esto? Ve a la sección de solución de problemas.
#
# ### Nota: necesitarás configurar el Kernel en cada notebook...

# %%
# imports

import os
from dotenv import load_dotenv
from scraper import fetch_website_contents
from IPython.display import Markdown, display
from google import genai

# Si obtienes un error al ejecutar esta celda, ¡por favor ve al notebook de solución de problemas!

# %% [markdown]
# # Conectando con OpenAI (u Ollama)
#
# La siguiente celda es donde cargamos las variables de entorno en tu archivo `.env` y nos conectamos a OpenAI.
#
# Si prefieres usar Ollama gratis en su lugar, por favor revisa la sección del README "Alternativa Gratuita a las APIs de Pago", y si no estás seguro de cómo hacerlo, hay una solución completa en la carpeta de soluciones (day1_with_ollama.ipynb).
#
# ## Solución de problemas si tienes inconvenientes:
#
# Si obtienes un "Name Error" - ¿has ejecutado todas las celdas de arriba hacia abajo? Ve a la guía de Fundamentos de Python para una forma infalible de encontrar y arreglar todos los Name Errors.
#
# Si eso no lo arregla, ve al notebook de [solución de problemas](../setup/troubleshooting.ipynb) para código paso a paso para identificar la causa raíz y arreglarla.
#
# O, ¡contáctame! Escríbeme o envía un correo a ed@edwarddonner.com y haremos que esto funcione.
#
# ¿Alguna preocupación sobre los costos de la API? Revisa mis notas en el README - los costos deberían ser mínimos, y puedes controlarlo en cada punto. También puedes usar Ollama como alternativa gratuita, que discutimos durante el Día 2.

# %%
# Carga las variables de entorno en un archivo llamado .env

load_dotenv(override=True)
api_key = os.getenv('GOOGLE_API_KEY')

# Verifica la clave

if not api_key:
    print("No se encontró ninguna API key - por favor verifica que tu archivo .env tenga GOOGLE_API_KEY definida!")
elif api_key.strip() != api_key:
    print("Se encontró una API key, pero parece tener espacios o tabulaciones al principio o al final - por favor elimínalos")
else:
    print("¡API key encontrada y se ve bien hasta ahora!")
# Out:
# ¡API key encontrada y se ve bien hasta ahora!

# %% [markdown]
# # Hagamos una llamada rápida a un modelo de Frontera para empezar, ¡como adelanto!

# %%
# Para darte un adelanto -- llamar a Gemini con este mensaje es así de fácil. Si tienes problemas, ve al notebook de Solución de problemas.

message = "¡Hola, Gemini! ¡Este es mi primer mensaje para ti! ¡Hola!"

messages = [{"role": "user", "content": message}]

messages
# Out:
# [{'role': 'user',
#   'content': '¡Hola, Gemini! ¡Este es mi primer mensaje para ti! ¡Hola!'}]

# %%
client = genai.Client(api_key=os.getenv('GOOGLE_API_KEY'))

response = client.models.generate_content(model="gemini-3.6-flash", contents=message)
response.text
# Out:
# '¡Hola! ¡Qué alegría recibir tu primer mensaje! 😊 ¡Bienvenido/a!\n\nMe da mucho gusto saludarte. Estoy aquí para ayudarte en lo que necesites: responder preguntas, buscar ideas, redactar textos, aprender sobre algún tema o simplemente charlar un rato.\n\n¿De qué te gustaría hablar hoy o en qué te puedo ayudar?'

# %% [markdown]
# ## Bien, sigamos adelante con nuestro primer proyecto

# %%
# Probemos esta utilidad

ed = fetch_website_contents("https://edwarddonner.com")
print(ed)
# Out:
# Home - Edward Donner
#
# Skip to content
# Avatar
# Curriculum
# Proficiency
# C4
# Outsmart
# An arena that pits LLMs against each other in a battle of diplomacy and deviousness
# About
# Posts
# Well, hi there.
# I’m Ed. I like writing code and experimenting with LLMs, and hopefully you’re here because you do too. I also enjoy amateur electronic music production (
# very
# amateur) and losing myself in
# Hacker News
# , nodding my head sagely to things I only half understand.
# I’m the co-founder and CTO of AI startup
# Nebula.io
# . I was previously founder and CEO of AI startup untapt,
# acquired in 2021
# , and a Managing Director at JPMorgan.
# I will happily drone on for hours about LLMs to anyone in my vicinity. My friends got fed up with my impromptu lectures, and convinced me to make some Udemy courses. To my total joy (and shock) they’ve become best-selling, top-rated courses, with 900,000 enrollments across 194 countries. The
# full curriculum is here
# ...

# %% [markdown]
# ## Tipos de prompts
#
# Puede que ya sepas esto - pero si no, ¡te familiarizarás mucho con ello!
#
# Modelos como GPT han sido entrenados para recibir instrucciones de una forma particular.
#
# Esperan recibir:
#
# **Un system prompt** que les dice qué tarea están realizando y qué tono deberían usar
#
# **Un user prompt** -- el inicio de la conversación al que deben responder

# %%
# Define nuestro system prompt - puedes experimentar con esto después, cambiando la última oración a 'Responde en markdown en español."

system_prompt = """
Eres un asistente sarcástico que analiza el contenido de un sitio web,
y ofrece un resumen corto, sarcástico y humorístico, ignorando el texto que pueda ser de navegación.
Responde en markdown. No envuelvas el markdown en un bloque de código - responde solo con el markdown.
"""

# %%
# Define nuestro user prompt

user_prompt_prefix = """
Aquí está el contenido de un sitio web.
Proporciona un resumen corto de este sitio web.
Si incluye noticias o anuncios, resúmelos también.

"""

# %% [markdown]
# ## Mensajes
#
# La API de OpenAI espera recibir mensajes en una estructura particular.
# Muchas de las otras APIs comparten esta estructura:
#
# ```python
# [
#     {"role": "system", "content": "aquí va el mensaje del sistema"},
#     {"role": "user", "content": "aquí va el mensaje del usuario"}
# ]
# ```
# Para darte un adelanto, las siguientes 2 celdas hacen una llamada bastante simple - ¡no exigiremos al todopoderoso GPT (todavía)!

# %%
response = client.models.generate_content(
    model="gemini-2.5-flash",
    config=genai.types.GenerateContentConfig(system_instruction="Eres un asistente útil"),
    contents="¿Cuánto es 2 + 2?"
)
response.text

# %% [markdown]
# ## Y ahora construyamos mensajes útiles para GPT-4.1-mini, usando una función

# %%
# Mira cómo esta función arma el prompt para Gemini

def messages_for(website):
    return {
        "system_instruction": system_prompt,
        "contents": user_prompt_prefix + website
    }

# %%
# Prueba esto, y luego intenta con algunos otros sitios web

messages_for(ed)

# %% [markdown]
# ## Hora de juntar todo - ¡la API de Gemini es muy simple!

# %%
# Y ahora: llama a la API de Gemini. ¡Te familiarizarás mucho con esto!

def summarize(url):
    website = fetch_website_contents(url)
    prompt = messages_for(website)
    response = client.models.generate_content(
        model="gemini-2.5-flash",
        config=genai.types.GenerateContentConfig(system_instruction=prompt["system_instruction"]),
        contents=prompt["contents"]
    )
    return response.text

# %%
summarize("https://edwarddonner.com")

# %%
# Una función para mostrar esto de forma más agradable en la salida, usando markdown

def display_summary(url):
    summary = summarize(url)
    display(Markdown(summary))

# %%
display_summary("https://edwarddonner.com")

# %% [markdown]
# # Probemos con más sitios web
#
# Ten en cuenta que esto solo funcionará en sitios web que puedan ser scrapeados usando este enfoque simplista.
#
# Los sitios web renderizados con Javascript, como las apps de React, no aparecerán. Revisa la carpeta community-contributions para ver una implementación con Selenium que evita este problema. Necesitarás informarte sobre cómo instalar Selenium (¡pregúntale a ChatGPT!)
#
# También los sitios web protegidos con CloudFront (y similares) pueden dar errores 403 - muchas gracias a Andy J por señalar esto.
#
# ¡Pero muchos sitios web funcionarán sin problema!

# %%
display_summary("https://cnn.com")

# %%
display_summary("https://anthropic.com")

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Aplicaciones de negocio</h2>
#             <span style="color:#181;">En este ejercicio, experimentaste llamando a la API en la Nube de un Modelo de Frontera (un modelo líder en la frontera de la IA) por primera vez. Usaremos APIs como OpenAI en muchas etapas del curso, además de construir nuestros propios LLMs.
#
# Más específicamente, hemos aplicado esto a la Resumización - un caso de uso clásico de IA Generativa para hacer un resumen. Esto puede aplicarse a cualquier vertical de negocio - resumir noticias, resumir el desempeño financiero, resumir un currículum en una carta de presentación - las aplicaciones son ilimitadas. Considera cómo podrías aplicar la Resumización en tu negocio, e intenta prototipar una solución.</span>
#         </td>
#     </tr>
# </table>
#
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Antes de continuar - ahora inténtalo tú mismo</h2>
#             <span style="color:#900;">Usa la celda de abajo para crear tu propio ejemplo comercial simple. Quédate con el caso de uso de resumización por ahora. Aquí hay una idea: escribe algo que tome el contenido de un correo electrónico, y sugiera una línea de asunto corta apropiada para el correo. Ese es el tipo de función que podría integrarse en una herramienta comercial de correo electrónico.</span>
#         </td>
#     </tr>
# </table>

# %%
# Paso 1: Crea tus prompts

system_prompt = "algo aquí"
user_prompt = """
    Puedes pegar
    mucho texto aquí
"""

# Paso 2: Arma la llamada a Gemini
# response = client.models.generate_content(model="gemini-2.5-flash", config=genai.types.GenerateContentConfig(system_instruction=system_prompt), contents=user_prompt)

# Paso 3: imprime el resultado
# print(

# %% [markdown]
# ## Un ejercicio extra para quienes disfrutan el web scraping
#
# Puede que notes que si intentas `display_summary("https://openai.com")` - ¡no funciona! Eso es porque OpenAI tiene un sitio web sofisticado que usa Javascript. Hay muchas formas de evitar esto con las que algunos de ustedes pueden estar familiarizados. Por ejemplo, Selenium es un framework enormemente popular que ejecuta un navegador por detrás, renderiza la página, y te permite consultarla. Si tienes experiencia con Selenium, Playwright o un framework similar de automatización de navegador, siéntete libre de implementar una versión alternativa de las funciones de scraping en `scraper.py` (o en un módulo separado) usando una de estas herramientas. En la carpeta community-contributions, encontrarás ejemplos aportados por otros estudiantes, incluyendo una implementación con Selenium (¡gracias!)

# %% [markdown]
# # Compartiendo tu código
#
# ¡Me encantaría que compartieras tu código después para poder compartirlo con otros! Notarás que algunos estudiantes ya han hecho cambios (incluyendo una implementación con Selenium) que encontrarás en la carpeta community-contributions. Si quieres agregar tus cambios a esa carpeta, envía un Pull Request con tus nuevas versiones en esa carpeta y fusionaré tus cambios.
#
# Si no eres experto con git (¡y yo no lo soy!) entonces te he dado instrucciones completas en la carpeta de guías, guía 3, y las pego aquí:
#
# Aquí están los pasos generales para hacer un PR y las instrucciones clave:
# https://edwarddonner.com/pr
#
# Por favor revisa antes de enviar:
# 1. Tu PR solo contiene cambios en community-contributions (a menos que lo hayamos discutido)
# 2. Todas las salidas del notebook están limpias
# 3. Menos de 2,000 líneas de código en total, y no demasiados archivos
# 4. ¡No incluyas archivos de prueba innecesarios, ni un README demasiado extenso, ni .env.example, ni emojis, ni otros artefactos de LLM!
#
# ¡Muchas gracias!
#
# Pasos detallados aquí:
#
# https://chatgpt.com/share/6873c22b-2a1c-8012-bc9a-debdcf7c835b
